# %%
# Model listesini tanımlayalım
MODEL_LIST = [
'AdaBoost_7_Sosyal',
'LogisticRegression_7_Sosyal',
'LogisticRegression_6_Sosyal',
'AdaBoost_6_Sosyal',
'SVM_7_Sosyal',
'NeuralNetwork_7_Sosyal',
'KNN_6_Sosyal',
'RandomForest_7_Sosyal',
'DecisionTree_7_Sosyal',
'XGBoost_7_Sosyal',
'KNN_7_Sosyal',
'LogisticRegression_7_Duyusal',
'LogisticRegression_9_Duyusal',
'AdaBoost_9_Duyusal',
'AdaBoost_7_Duyusal',
'NeuralNetwork_7_Duyusal',
'SVM_7_Duyusal',
'AdaBoost_10_Duyusal',
'LogisticRegression_10_Duyusal',
'LogisticRegression_6_Duyusal',
'NeuralNetwork_9_Duyusal',
'KNN_7_Duyusal',
'NeuralNetwork_6_Duyusal',
'LightGBM_7_Duyusal',
'AdaBoost_6_Duyusal',
'XGBoost_6_Duyusal',
'NeuralNetwork_10_Motor',
'RandomForest_10_Motor',
'SVM_10_Motor',
'SVM_9_Motor',
'LightGBM_10_Motor',
'LogisticRegression_9_Motor',
'XGBoost_10_Motor',
'LogisticRegression_7_Motor',
'KNN_7_Motor',
'KNN_9_Motor',
'SVM_7_Motor',
'NeuralNetwork_9_Motor',
'NeuralNetwork_7_Motor',
'RandomForest_9_Motor',
'LightGBM_9_Motor',
'RandomForest_7_Motor',
'AdaBoost_5_Motor',
'LightGBM_5_Motor',
'AdaBoost_6_Motor',
'XGBoost_7_Motor',
'XGBoost_9_Motor',
'SVM_5_Motor',
'XGBoost_5_Motor',
'NeuralNetwork_5_Motor',
'LightGBM_7_Motor',
'LightGBM_8_Dil',
'AdaBoost_6_Dil',
'LogisticRegression_6_Dil',
'SVM_8_Dil',
'RandomForest_6_Dil',
'KNN_8_Dil',
'NeuralNetwork_8_Dil',
'DecisionTree_6_Dil',
'LogisticRegression_8_Dil',
'SVM_6_Dil',
'AdaBoost_8_Dil',
'LogisticRegression_9_Ortak_Dikkat',
'SVM_9_Ortak_Dikkat',
'LogisticRegression_10_Ortak_Dikkat',
'SVM_10_Ortak_Dikkat',
'KNN_9_Ortak_Dikkat',
'NeuralNetwork_10_Ortak_Dikkat',
'NeuralNetwork_9_Ortak_Dikkat',
'KNN_10_Ortak_Dikkat',
'AdaBoost_10_Ortak_Dikkat',
'RandomForest_9_Ortak_Dikkat',
'AdaBoost_9_Ortak_Dikkat',
'XGBoost_10_Ortak_Dikkat',
'XGBoost_9_Ortak_Dikkat',
'LogisticRegression_8_Ortak_Dikkat',
'KNN_8_Ortak_Dikkat',
'NeuralNetwork_8_Ortak_Dikkat',
'RandomForest_10_Ortak_Dikkat',
'LightGBM_10_Ortak_Dikkat',
'AdaBoost_8_Ortak_Dikkat',
'LightGBM_9_Ortak_Dikkat',
'SVM_8_Ortak_Dikkat',
'LightGBM_8_Ortak_Dikkat',
'XGBoost_8_Ortak_Dikkat',
'LogisticRegression_7_Ortak_Dikkat',
'NeuralNetwork_7_Ortak_Dikkat',
'LogisticRegression_7_Iletisim',
'AdaBoost_7_Iletisim',
'NeuralNetwork_7_Iletisim',
'SVM_7_Iletisim',
'KNN_7_Iletisim',
'RandomForest_7_Iletisim',
'XGBoost_7_Iletisim',
'LightGBM_7_Iletisim',
'DecisionTree_7_Iletisim',
'KNN_13_Otizm',
'AdaBoost_12_Otizm',
'NeuralNetwork_8_Otizm',
'LightGBM_8_Otizm',
'AdaBoost_8_Otizm',
'AdaBoost_13_Otizm',
'RandomForest_8_Otizm',
'LogisticRegression_12_Otizm',
'XGBoost_8_Otizm',
'SVM_12_Otizm',
'LogisticRegression_8_Otizm',
'LightGBM_13_Otizm',
'KNN_12_Otizm',
'KNN_8_Otizm',
'NeuralNetwork_13_Otizm',
'LightGBM_7_DEHB',
'NeuralNetwork_7_DEHB',
'DecisionTree_7_DEHB',
'XGBoost_7_DEHB',
'SVM_7_DEHB',
'RandomForest_7_DEHB',
'KNN_7_DEHB',
'NeuralNetwork_20_Dil ve Konuşma Bozuklukları',
'KNN_20_Dil ve Konuşma Bozuklukları',
'DecisionTree_8_Dil ve Konuşma Bozuklukları',
'XGBoost_20_Dil ve Konuşma Bozuklukları',
'DecisionTree_20_Dil ve Konuşma Bozuklukları',
'AdaBoost_13_Gelişimsel Koordinasyon Bozukluğu',
'XGBoost_13_Gelişimsel Koordinasyon Bozukluğu',
'LightGBM_13_Gelişimsel Koordinasyon Bozukluğu',
'RandomForest_13_Gelişimsel Koordinasyon Bozukluğu',
'KNN_13_Gelişimsel Koordinasyon Bozukluğu',
'SVM_13_Gelişimsel Koordinasyon Bozukluğu',
'NeuralNetwork_13_Gelişimsel Koordinasyon Bozukluğu',
'LogisticRegression_13_Gelişimsel Koordinasyon Bozukluğu',
'DecisionTree_13_Gelişimsel Koordinasyon Bozukluğu',
'KNN_20_Zihinsel Yetersizlik',
'RandomForest_7_Zihinsel Yetersizlik',
'XGBoost_7_Zihinsel Yetersizlik',
'DecisionTree_7_Zihinsel Yetersizlik',
'AdaBoost_20_Zihinsel Yetersizlik',
'LightGBM_7_Zihinsel Yetersizlik',
'SVM_7_Zihinsel Yetersizlik',
'DecisionTree_6_Zihinsel Yetersizlik',
'LightGBM_6_Zihinsel Yetersizlik',
'XGBoost_6_Zihinsel Yetersizlik',
'RandomForest_6_Zihinsel Yetersizlik',
'NeuralNetwork_7_Zihinsel Yetersizlik',
'KNN_7_Zihinsel Yetersizlik'
]

# %%
# Tek Hücre: Colab’da 145 Modeli Eğit, .pkl Üret, Zip’le ve İndir

# 0) Gerekli kütüphaneleri yükleyelim
# !pip install -q scikit-learn pandas numpy joblib xgboost lightgbm catboost openpyxl

# 1) İçe aktarımlar
import os, zipfile
import pandas as pd
import numpy as np
from joblib import dump
from google.colab import files

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier

# LightGBM / CatBoost varsa al
try:
    from lightgbm import LGBMClassifier; has_lgb = True
except ImportError:
    has_lgb = False
try:
    from catboost import CatBoostClassifier; has_cb = True
except ImportError:
    has_cb = False

# 2) Gerekli dosyaları yükleyin
print("Lütfen 'cocuklar600.csv' ve 'selected_features.xlsx' dosyalarını seçin:")
uploaded = files.upload()

# 3) Verileri oku
df       = pd.read_csv('cocuklar600.csv')
sel_feat = pd.read_excel('selected_features.xlsx')
cfg      = sel_feat.set_index('Model')


# 5) Algoritma sınıf haritası
algo_cls = {
    'LogisticRegression': (LogisticRegression, {'max_iter':1000}),
    'DecisionTree':       (DecisionTreeClassifier, {}),
    'RandomForest':       (RandomForestClassifier, {}),
    'AdaBoost':           (AdaBoostClassifier, {}),
    'SVM':                (SVC, {'probability':True}),
    'KNN':                (KNeighborsClassifier, {}),
    'XGBoost':            (XGBClassifier, {'use_label_encoder':False,'eval_metric':'logloss'}),
    'NeuralNetwork':      (MLPClassifier, {'max_iter':1000})
}
if has_lgb: algo_cls['LightGBM'] = (LGBMClassifier,{})
if has_cb: algo_cls['CatBoost'] = (CatBoostClassifier,{'verbose':0})

# 6) models/ klasörünü oluştur
os.makedirs('models', exist_ok=True)

# 7) Modelleri eğit ve kaydet
for m in MODEL_LIST:
    print(f"\n▶ Eğitiliyor: {m}")
    algo = m.split('_')[0]
    label = '_'.join(m.split('_')[2:])
    feats = [q.strip() for q in cfg.loc[m,'Selected_Questions'].split(',')]
    cls, params = algo_cls[algo]
    clf = cls(**params)
    X = df[feats].astype(int)
    y = df[label]
    clf.fit(X, y)
    dump(clf, f'models/{m}.pkl')
    print(f"✔ Kaydedildi: models/{m}.pkl")

# 8) models.zip oluştur
with zipfile.ZipFile('models.zip','w', zipfile.ZIP_DEFLATED) as z:
    for fn in os.listdir('models'):
        z.write(os.path.join('models', fn), arcname=fn)
print("\nmodels.zip oluşturuldu.")

# 9) İndir
files.download('models.zip')
print("models.zip indirildi.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 6.0 MB/s eta 0:00:00
# Lütfen 'cocuklar600.csv' ve 'selected_features.xlsx' dosyalarını seçin:
#      <input type="file" id="files-1c80d707-d359-42e9-93d1-629fafe7fad4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c80d707-d359-42e9-93d1-629fafe7fad4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
DURRR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-56bdebdb755f> in <cell line: 0>()
# ----> 1 DURRR
#
# NameError: name 'DURRR' is not defined

# %%
import os
import zipfile
import pandas as pd
import numpy as np
from joblib import dump
from google.colab import files

# ML modeller
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier

# LightGBM / CatBoost varsa al
try:
    from lightgbm import LGBMClassifier; has_lgb = True
except ImportError:
    has_lgb = False
try:
    from catboost import CatBoostClassifier; has_cb = True
except ImportError:
    has_cb = False

# —————————————
# 1) Gerçek verileri oku
# —————————————
# (Colab’de /mnt/data klasöründe ise tam yol verin, yoksa direkt dosya adı)
df       = pd.read_csv('cocuklar600.csv')
sel_feat = pd.read_excel('selected_features.xlsx')


# 2) Yalnızca selected_features’de tanımlı modelleri al
models_to_build = MODEL_LIST
cfg = sel_feat.merge(perf, on='Model').set_index('Model')

# 3) Algoritma sınıf haritası
algo_cls = {
    'LogisticRegression': (LogisticRegression, {'max_iter':1000}),
    'DecisionTree':       (DecisionTreeClassifier, {}),
    'RandomForest':       (RandomForestClassifier, {}),
    'AdaBoost':           (AdaBoostClassifier, {}),
    'SVM':                (SVC, {'probability':True}),
    'KNN':                (KNeighborsClassifier, {}),
    'XGBoost':            (XGBClassifier, {'use_label_encoder':False,'eval_metric':'logloss'}),
    'NeuralNetwork':      (MLPClassifier, {'max_iter':1000})
}
if has_lgb:
    algo_cls['LightGBM'] = (LGBMClassifier,{})
if has_cb:
    algo_cls['CatBoost'] = (CatBoostClassifier,{'verbose':0})

# 4) Klasör oluştur
os.makedirs('models', exist_ok=True)

# 5) Her modeli eğit, kaydet
for m in models_to_build:
    algo  = m.split('_')[0]
    label = '_'.join(m.split('_')[2:])
    feats = [q.strip() for q in cfg.loc[m,'Selected_Questions'].split(',')]
    cls, params = algo_cls[algo]
    clf = cls(**params)

    X = df[feats].astype(int)   # soru sütunları
    y = df[label]               # ilgili etiket (0/1)
    clf.fit(X, y)

    dump(clf, f'models/{m}.pkl')

# 6) models/ klasörünü zip’le
with zipfile.ZipFile('models.zip','w', zipfile.ZIP_DEFLATED) as z:
    for fname in os.listdir('models'):
        z.write(os.path.join('models', fname), arcname=fname)

# 7) İndir
files.download('models.zip')

# %%
DUR

# %%
# Gerekli kütüphaneleri yükleyelim
# !pip install -q scikit-learn pandas numpy joblib openpyxl

# İçe aktarımlar
import pandas as pd
import numpy as np
import os
import zipfile
from google.colab import files
import joblib

# ML modelleri
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier

# %%
# Model oluşturma fonksiyonu
def create_model(model_name):
    if 'AdaBoost' in model_name:
        return AdaBoostClassifier(random_state=42)
    elif 'LogisticRegression' in model_name:
        return LogisticRegression(random_state=42)
    elif 'RandomForest' in model_name:
        return RandomForestClassifier(random_state=42)
    elif 'SVM' in model_name:
        return SVC(random_state=42)
    elif 'KNN' in model_name:
        return KNeighborsClassifier()
    elif 'XGBoost' in model_name:
        return XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
    elif 'NeuralNetwork' in model_name:
        return MLPClassifier(max_iter=1000, random_state=42)
    else:
        raise ValueError(f"Bilinmeyen model tipi: {model_name}")

# %%
# 'models' klasörünü oluştur
os.makedirs('models', exist_ok=True)

performance_data = []
selected_features = []

# Örnek veri seti (kendi veri setinizle değiştirin)
np.random.seed(42)
X = np.random.rand(100, 10)
y = np.random.randint(0, 2, 100)

for model_name in MODEL_LIST:
    print(f"\nModel oluşturuluyor: {model_name}")

    # Modeli oluştur ve eğit
    model = create_model(model_name)
    model.fit(X, y)

    # Performans hesapla (burada train==test olarak örneklendi)
    y_pred = model.predict(X)
    f1 = f1_score(y, y_pred)

    # Performans verilerini kaydet
    performance_data.append({
        'Model': model_name,
        'Train_F1': f1,
        'Test_F1': f1
    })

    # Seçilen özellikleri kaydet (örnek olarak sabit liste)
    selected_features.append({
        'Model': model_name,
        'Selected_Questions': 'Q2,Q4,Q8,Q9,Q13'
    })

    # Modeli disk’e kaydet
    joblib.dump(model, f'models/{model_name}.pkl')
    print(f"Model kaydedildi: {model_name}")

# %%
# Performans ve özellik verilerini Excel’e yaz
pd.DataFrame(performance_data).to_excel("model_performance.xlsx", index=False)
pd.DataFrame(selected_features).to_excel("selected_features.xlsx", index=False)
print("Meta veriler kaydedildi.")

# %%
# models/ klasörünü zip’le
with zipfile.ZipFile('models.zip', 'w', zipfile.ZIP_DEFLATED) as z:
    for root, dirs, files in os.walk('models'):
        for file in files:
            path = os.path.join(root, file)
            z.write(path, arcname=os.path.relpath(path, 'models'))
print("models.zip oluşturuldu.")

# Excel dosyalarını zip’le
with zipfile.ZipFile('meta_data.zip', 'w', zipfile.ZIP_DEFLATED) as z:
    z.write('model_performance.xlsx')
    z.write('selected_features.xlsx')
print("meta_data.zip oluşturuldu.")

# %%
files.download('models.zip')
files.download('meta_data.zip')
print("Zip dosyaları indirildi.")
